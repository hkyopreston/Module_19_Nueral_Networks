# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
train_x = np.asarray(X_train_scaled)
train_y = np.asarray(y_train)

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(train_x, train_y, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(train_x, train_y,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/100
# 576/576 [==============================] - 1s 987us/sample - loss: 0.6873 - accuracy: 0.6111
# Epoch 2/100
# 576/576 [==============================] - 0s 49us/sample - loss: 0.6495 - accuracy: 0.6562
# Epoch 3/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.6212 - accuracy: 0.6944
# Epoch 4/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5954 - accuracy: 0.7066
# Epoch 5/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.5749 - accuracy: 0.7309
# Epoch 6/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.5585 - accuracy: 0.7500
# Epoch 7/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.5439 - accuracy: 0.7552
# Epoch 8/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.5321 - accuracy: 0.7569
# Epoch 9/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.5213 - accuracy: 0.7639
# Epoch 10/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.5126 - accuracy: 0.7674
# Epoch 11/100
# 576/576 [==============================] - 0s 51us/sample - loss: 0.5047 - accuracy: 0.7726
# Epoch 12/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4978 - accuracy: 0.7726
# Epoch 13/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4922 - accuracy: 0.7743
# Epoch 14/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4866 - accuracy: 0.7795
# Epoch 15/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4822 - accuracy: 0.7778
# Epoch 16/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4782 - accuracy: 0.7795
# Epoch 17/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4746 - accuracy: 0.7812
# Epoch 18/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4711 - accuracy: 0.7795
# Epoch 19/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4688 - accuracy: 0.7795
# Epoch 20/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4658 - accuracy: 0.7847
# Epoch 21/100
# 576/576 [==============================] - 0s 51us/sample - loss: 0.4637 - accuracy: 0.7899
# Epoch 22/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4615 - accuracy: 0.7917
# Epoch 23/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4596 - accuracy: 0.7934
# Epoch 24/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4580 - accuracy: 0.7917
# Epoch 25/100
# 576/576 [==============================] - 0s 51us/sample - loss: 0.4565 - accuracy: 0.7899
# Epoch 26/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4550 - accuracy: 0.7917
# Epoch 27/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4535 - accuracy: 0.7934
# Epoch 28/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4522 - accuracy: 0.7951
# Epoch 29/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4513 - accuracy: 0.7917
# Epoch 30/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4500 - accuracy: 0.7917
# Epoch 31/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4488 - accuracy: 0.7917
# Epoch 32/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4477 - accuracy: 0.7934
# Epoch 33/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4470 - accuracy: 0.7917
# Epoch 34/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4461 - accuracy: 0.7934
# Epoch 35/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4452 - accuracy: 0.7951
# Epoch 36/100
# 576/576 [==============================] - 0s 49us/sample - loss: 0.4446 - accuracy: 0.7969
# Epoch 37/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4442 - accuracy: 0.8003
# Epoch 38/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4432 - accuracy: 0.7986
# Epoch 39/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4427 - accuracy: 0.8003
# Epoch 40/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4421 - accuracy: 0.8003
# Epoch 41/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4415 - accuracy: 0.8003
# Epoch 42/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4411 - accuracy: 0.8003
# Epoch 43/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4411 - accuracy: 0.8056
# Epoch 44/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4398 - accuracy: 0.8038
# Epoch 45/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4392 - accuracy: 0.8038
# Epoch 46/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4388 - accuracy: 0.8038
# Epoch 47/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4383 - accuracy: 0.8038
# Epoch 48/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4378 - accuracy: 0.8038
# Epoch 49/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4375 - accuracy: 0.8038
# Epoch 50/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4368 - accuracy: 0.8038
# Epoch 51/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4363 - accuracy: 0.8038
# Epoch 52/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4360 - accuracy: 0.8021
# Epoch 53/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4358 - accuracy: 0.8038
# Epoch 54/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4350 - accuracy: 0.8056
# Epoch 55/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4346 - accuracy: 0.8056
# Epoch 56/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4345 - accuracy: 0.8038
# Epoch 57/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4338 - accuracy: 0.8056
# Epoch 58/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4337 - accuracy: 0.8038
# Epoch 59/100
# 576/576 [==============================] - 0s 49us/sample - loss: 0.4331 - accuracy: 0.8056
# Epoch 60/100
# 576/576 [==============================] - 0s 51us/sample - loss: 0.4324 - accuracy: 0.8056
# Epoch 61/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4325 - accuracy: 0.8021
# Epoch 62/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4319 - accuracy: 0.8021
# Epoch 63/100
# 576/576 [==============================] - 0s 50us/sample - loss: 0.4318 - accuracy: 0.8073
# Epoch 64/100
# 576/576 [==============================] - 0s 48us/sample - loss: 0.4309 - accuracy: 0.8090
# Epoch 65/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4305 - accuracy: 0.8073
# Epoch 66/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4300 - accuracy: 0.8073
# Epoch 67/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4300 - accuracy: 0.8056
# Epoch 68/100
# 576/576 [==============================] - 0s 56us/sample - loss: 0.4296 - accuracy: 0.8073
# Epoch 69/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4293 - accuracy: 0.8056
# Epoch 70/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4283 - accuracy: 0.8056
# Epoch 71/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4281 - accuracy: 0.8056
# Epoch 72/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4275 - accuracy: 0.8056
# Epoch 73/100
# 576/576 [==============================] - 0s 51us/sample - loss: 0.4271 - accuracy: 0.8056
# Epoch 74/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4267 - accuracy: 0.8056
# Epoch 75/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4264 - accuracy: 0.8056
# Epoch 76/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4259 - accuracy: 0.8038
# Epoch 77/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4258 - accuracy: 0.8073
# Epoch 78/100
# 576/576 [==============================] - 0s 54us/sample - loss: 0.4253 - accuracy: 0.8056
# Epoch 79/100
# 576/576 [==============================] - 0s 58us/sample - loss: 0.4250 - accuracy: 0.8090
# Epoch 80/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4245 - accuracy: 0.8056
# Epoch 81/100
# 576/576 [==============================] - 0s 57us/sample - loss: 0.4240 - accuracy: 0.8056
# Epoch 82/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4239 - accuracy: 0.8056
# Epoch 83/100
# 576/576 [==============================] - 0s 50us/sample - loss: 0.4239 - accuracy: 0.8073
# Epoch 84/100
# 576/576 [==============================] - 0s 46us/sample - loss: 0.4232 - accuracy: 0.8073
# Epoch 85/100
# 576/576 [==============================] - 0s 44us/sample - loss: 0.4228 - accuracy: 0.8073
# Epoch 86/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4228 - accuracy: 0.8073
# Epoch 87/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4222 - accuracy: 0.8073
# Epoch 88/100
# 576/576 [==============================] - 0s 46us/sample - loss: 0.4218 - accuracy: 0.8056
# Epoch 89/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4219 - accuracy: 0.8073
# Epoch 90/100
# 576/576 [==============================] - 0s 44us/sample - loss: 0.4212 - accuracy: 0.8090
# Epoch 91/100
# 576/576 [==============================] - 0s 49us/sample - loss: 0.4211 - accuracy: 0.8073
# Epoch 92/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4209 - accuracy: 0.8073
# Epoch 93/100
# 576/576 [==============================] - 0s 45us/sample - loss: 0.4202 - accuracy: 0.8073
# Epoch 94/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4205 - accuracy: 0.8090
# Epoch 95/100
# 576/576 [==============================] - 0s 47us/sample - loss: 0.4196 - accuracy: 0.8073
# Epoch 96/100
# 576/576 [==============================] - 0s 48us/sample - loss: 0.4198 - accuracy: 0.8090
# Epoch 97/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4195 - accuracy: 0.8073
# Epoch 98/100
# 576/576 [==============================] - 0s 55us/sample - loss: 0.4189 - accuracy: 0.8073
# Epoch 99/100
# 576/576 [==============================] - 0s 53us/sample - loss: 0.4186 - accuracy: 0.8073
# Epoch 100/100
# 576/576 [==============================] - 0s 52us/sample - loss: 0.4184 - accuracy: 0.8073
# 576/1 - 0s - loss: 0.4357 - accuracy: 0.8073
# Loss: 0.41734133660793304, Accuracy: 0.8072916865348816
